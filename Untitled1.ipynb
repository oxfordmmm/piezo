# %%
import piezo

# %load_ext autoreload

# %autoreload 2

# %%
cat=piezo.ResistanceCatalogue("config/NC_00962.3_NEJM2018_GM3_RUS_v1.0.csv")

# %%
cat.predict('rpoB_S450L')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-81-dff39c265e99> in <module>()
# ----> 1 cat.predict('rpoB_S450L')
#
# ~/packages/piezo/piezo/catalogue.py in predict(self, mutation, verbose)
#      28     def predict(self, mutation, verbose=False):
#      29
# ---> 30         return predict(self.catalogue, mutation=mutation, verbose=verbose)
#      31
#      32 def parse_json(data):
#
# ~/packages/piezo/piezo/catalogue.py in predict(catalogue, mutation, verbose)
#     153     if catalogue.grammar=="GM1":
#     154
# --> 155         result = predict_GM1(catalogue,mutation,verbose)
#     156
#     157         return(result)
#
# ~/packages/piezo/piezo/catalogue.py in predict_GM1(catalogue, gene_mutation, verbose)
#     215             if mutation_type=="SNP":
#     216                 process_snp_variants(mutation_affects, predictions, catalogue, before, after, mutation, rules_subset,
# --> 217                                      mutation_type_subset_vector, position_subset_vector, verbose)
#     218             elif mutation_type=="INDEL":
#     219                 process_indel_variants(variant_affects,
#
# ~/packages/piezo/piezo/catalogue.py in process_snp_variants(mutation_affects, predictions, catalogue, before, after, mutation, rules, rules_mutation_type_vector, rules_position_vector, verbose)
#     268
#     269     # PRIORITY=5: any het mutation at this specific position in the CDS or PROM  (e.g. rpoB_S450Z or rpoB_c-15z)
# --> 270     row=rules.loc[(rules_mutation_type_vector) & (rules_position_vector) & (before!=after) & (mutation[-1] in ["Z","z"]) & (rules.MUTATION.str[-1] in ['Z','z'])]
#     271     row_prediction(row, predictions, 5, "het SNP at specified position in the CDS")
#     272
#
# ~/Library/Python/3.5/lib/python/site-packages/pandas/core/generic.py in __nonzero__(self)
#    1553             "The truth value of a {0} is ambiguous. "
#    1554             "Use a.empty, a.bool(), a.item(), a.any() or a.all().".format(
# -> 1555                 self.__class__.__name__
#    1556             )
#    1557         )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
cat.catalogue.rules
# Out:
#      DRUG    MUTATION PREDICTION EVIDENCE                      SOURCE  \
# 0     EMB  2723_indel          S       {}  {'PUBLICATION': 'LID2015'}
# 1     EMB      A1015T          S       {}  {'PUBLICATION': 'LID2015'}
# 2     EMB      A1016S          S       {}  {'PUBLICATION': 'LID2015'}
# 3     EMB       A109T          S       {}  {'PUBLICATION': 'LID2015'}
# 4     EMB       A201T          S       {}  {'PUBLICATION': 'LID2015'}
# ...   ...         ...        ...      ...                         ...
# 1146  PZA          *?          U       {}  {'PUBLICATION': 'LID2015'}
# 1147  PZA          *=          S       {}  {'PUBLICATION': 'LID2015'}
# 1148  PZA         -*?          U       {}  {'PUBLICATION': 'LID2015'}
# 1149  PZA     *_indel          U       {}  {'PUBLICATION': 'LID2015'}
# 1150  PZA    -*_indel          U       {}  {'PUBLICATION': 'LID2015'}
#
#                      OTHER  GENE POSITION MUTATION_AFFECTS MUTATION_TYPE
# 0     {'PHYLO_SNP': False}  embA     2723              CDS         INDEL
# 1     {'PHYLO_SNP': False}  embA     1015              CDS           SNP
# 2     {'PHYLO_SNP': False}  embA     1016              CDS           SNP
# 3     {'PHYLO_SNP': False}  embA      109              CDS           SNP
# 4     {'PHYLO_SNP': False}  embA      201              CDS           SNP
# ...                    ...   ...      ...              ...           ...
# 1146                    {}  panD        *              CDS           SNP
# 1147                    {}  panD        *              CDS           SNP
# 1148                    {}  panD       -*             PROM           SNP
# 1149                    {}  panD        *              CDS         INDEL
# 1150                    {}  panD       -*             PROM         INDEL
#
# [1151 rows x 10 columns]

# %%
piezo.ResistanceCatalogue.predict()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-45-48d2c01214f0> in <module>()
# ----> 1 piezo.ResistanceCatalogue.predict()
#
# TypeError: predict() missing 1 required positional argument: 'mutation'
